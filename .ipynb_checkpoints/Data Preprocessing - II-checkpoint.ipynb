# %%
import pandas as pd

# %%
pre_final = pd.read_csv('./cleaned/contest_pre-final.csv')
# Out:
# C:\Users\Aishwarya\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (4,5,11,15,21,22,28,32,34,35,40,41) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pre_final.head()
# Out:
#    DRIVER_NUMBER  LAPS  FL_KPH   HOUR MANUFACTURER TOTAL_TIME    KPH  \
# 0            0.0   NaN     NaN  08:18          NaN        NaN   63.0
# 1            0.0   NaN     NaN  08:20          NaN        NaN  101.9
# 2            0.0   NaN     NaN  08:22          NaN        NaN  103.4
# 3            0.0   NaN     NaN  08:24          NaN        NaN  102.9
# 4            0.0   NaN     NaN  08:26          NaN        NaN  106.3
#
#    Unnamed: 25  NUMBER  DRIVER_SHORTNAME  ... S1_IMPROVEMENT DRIVER_HOMETOWN  \
# 0          NaN     NaN               NaN  ...            0.0             NaN
# 1          NaN     NaN               NaN  ...            0.0             NaN
# 2          NaN     NaN               NaN  ...            0.0             NaN
# 3          NaN     NaN               NaN  ...            0.0             NaN
# 4          NaN     NaN               NaN  ...            0.0             NaN
#
#    FL_TIME  S1_LARGE DRIVER_LICENSE S3_IMPROVEMENT season_year  location  \
# ...

# %%
pre_final.columns
# Out:
# Index(['DRIVER_NUMBER', 'LAPS', 'FL_KPH', 'HOUR', 'MANUFACTURER', 'TOTAL_TIME',
#        'KPH', 'Unnamed: 25', 'NUMBER', 'DRIVER_SHORTNAME', 'S2_LARGE', 'GROUP',
#        'FL_LAPNUM', 'CROSSING_FINISH_LINE_IN_PIT', 'PIT_TIME', 'VEHICLE',
#        'TEAM', 'LAP_IMPROVEMENT', 'CLASS', 'S2_IMPROVEMENT', 'TOP_SPEED',
#        'DRIVER_COUNTRY', 'STATUS', 'ELAPSED', 'ï»¿POSITION', 'TIRES',
#        'DRIVER_NAME', 'S3_LARGE', 'GAP_PREVIOUS', 'LAP_NUMBER', 'ï»¿NUMBER',
#        'S2', 'GAP_FIRST', 'DIVISION', 'DRIVER_SECONDNAME', 'DRIVER_FIRSTNAME',
#        'S3', 'S1', 'LAP_TIME', 'S1_IMPROVEMENT', 'DRIVER_HOMETOWN', 'FL_TIME',
#        'S1_LARGE', 'DRIVER_LICENSE', 'S3_IMPROVEMENT', 'season_year',
#        'location', 'match_type', 'match_name'],
#       dtype='object')

# %%
final = pd.read_csv('./cleaned/race_final_processed.csv')

# %%
final.head()
# Out:
#     DRIVER_NAME   location season_year                 match_name match_type  \
# 0   MA Qing Hua     Buenos   2016-2017  Groups Qualifying Session          Q
# 1   MA Qing Hua   HongKong   2016-2017  Groups Qualifying Session          Q
# 2   MA Qing Hua   HongKong   2016-2017                      Race        Race
# 3   MA Qing Hua  Marrakesh   2016-2017  Groups Qualifying Session          Q
# 4   MA Qing Hua   Newyork2   2017-2018       Qualifying 2 Group 1          Q
#
#   GROUP                TEAM   mean_KPH    std_KPH  med_KPH  ...  \
# 0   4.0           TECHEETAH  55.950000  74.034080    55.95  ...
# 1   2.0           TECHEETAH  60.720000  44.706677    83.70  ...
# 2   2.0           TECHEETAH  19.200000   0.000000    19.20  ...
# 3   1.0           TECHEETAH  96.700000  21.620515    89.10  ...
# 4   1.0  NIO Formula E Team  74.933333  36.874698    93.10  ...
#
#          mean_S3         std_S3    med_S3    max_S3    min_S3  range_S3  \
# ...

# %%
final.columns
# Out:
# Index(['DRIVER_NAME', 'location', 'season_year', 'match_name', 'match_type',
#        'GROUP', 'TEAM', 'mean_KPH', 'std_KPH', 'med_KPH', 'max_KPH', 'min_KPH',
#        'range_KPH', 'skew_KPH', 'mean_S1', 'std_S1', 'med_S1', 'max_S1',
#        'min_S1', 'range_S1', 'skew_S1', 'mean_S2', 'std_S2', 'med_S2',
#        'max_S2', 'min_S2', 'range_S2', 'skew_S2', 'mean_S3', 'std_S3',
#        'med_S3', 'max_S3', 'min_S3', 'range_S3', 'skew_S3', 'Total_Lap_Num',
#        'PIT_TIME_cnt', 'cnt_CROSSING_FINISH_LINE_IN_PIT'],
#       dtype='object')

# %%
final.shape
# Out:
# (1908, 38)

# %% [markdown]
# ## Pre-Final Variables

# %%
pre_final.head()
# Out:
#    DRIVER_NUMBER  LAPS  FL_KPH   HOUR MANUFACTURER TOTAL_TIME    KPH  \
# 0            0.0   NaN     NaN  08:18          NaN        NaN   63.0
# 1            0.0   NaN     NaN  08:20          NaN        NaN  101.9
# 2            0.0   NaN     NaN  08:22          NaN        NaN  103.4
# 3            0.0   NaN     NaN  08:24          NaN        NaN  102.9
# 4            0.0   NaN     NaN  08:26          NaN        NaN  106.3
#
#    Unnamed: 25  NUMBER  DRIVER_SHORTNAME  ... S1_IMPROVEMENT DRIVER_HOMETOWN  \
# 0          NaN     NaN               NaN  ...            0.0             NaN
# 1          NaN     NaN               NaN  ...            0.0             NaN
# 2          NaN     NaN               NaN  ...            0.0             NaN
# 3          NaN     NaN               NaN  ...            0.0             NaN
# 4          NaN     NaN               NaN  ...            0.0             NaN
#
#    FL_TIME  S1_LARGE DRIVER_LICENSE S3_IMPROVEMENT season_year  location  \
# ...

# %%
pre_final['DRIVER_NUMBER'].unique()
# Out:
# array([ 0., nan,  1.])

# %%
pre_final['DRIVER_NUMBER'] = pre_final['DRIVER_NUMBER'].astype(float)
pre_final['DRIVER_NUMBER'].unique()
# Out:
# array([ 0., nan,  1.])

# %%
pre_final['LAPS'].unique()
# Out:
# array([nan, 25., 24., 23., 21., 14.,  2.,  0., 33., 31., 35., 34., 30.,
#        26., 20., 15., 29., 28., 17.,  6., 39., 27., 22.,  7.,  3., 38.,
#        37., 47., 46., 36., 32.])
